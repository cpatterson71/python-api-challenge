# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from pprint import pprint
from citipy import citipy

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

for city in cities:
    query_url = url + "appid=" + 'c69238b9553f803c3dbc5f5427b2aa7a' + "&q=" + city +'&units=Imperial'
    weather_response = requests.get(query_url)
    cities_weather = weather_response.json()
    pprint(cities_weather)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 29.85, 'lon': 80.53},
#  'dt': 1601387031,
#  'id': 1272864,
#  'main': {'feels_like': 64.94,
#           'grnd_level': 859,
#           'humidity': 66,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 65.71,
#           'temp_max': 65.71,
#           'temp_min': 65.71},
#  'name': 'Dhārchula',
#  'sys': {'country': 'IN', 'sunrise': 1601339401, 'sunset': 1601382372},
#  'timezone': 19800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 36, 'speed': 3.58}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 14.3, 'lon': -91.92},
#  'dt': 1601387031,
#  'id': 3598787,
#  'main': {'feels_like': 76.48,
#           'humidity': 94,
#           'pressure': 1015,
#           'temp': 71.6,
#           'temp_max': 71.6,
#           'temp_min': 71.6},
#  'name': 'Champerico',
#  'sys': {'country': 'GT',
#          'id': 7068,
#          'sunrise': 1601380623,
#          'sunset': 1601423906,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 360, 'speed': 4.7}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 35.13, 'lon': 140.3},
#  'dt': 1601387032,
#  'id': 2112309,
#  'main': {'feels_like': 59.22,
#           'humidity': 68,
#           'pressure': 1009,
#           'temp': 66.06,
#           'temp_max': 66.2,
#           'temp_min': 66},
#  'name': 'Katsuura',
#  'sys': {'country': 'JP',
#          'id': 8074,
#          'sunrise': 1601325112,
#          'sunset': 1601367977,
#          'type': 1},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 20, 'speed': 14.99}}
# {'base': 'stations',
#  'clouds': {'all': 91},
#  'cod': 200,
#  'coord': {'lat': 36.65, 'lon': 107.79},
#  'dt': 1601387032,
#  'id': 1786110,
#  'main': {'feels_like': 55.36,
#           'grnd_level': 870,
#           'humidity': 64,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 61.07,
#           'temp_max': 61.07,
#           'temp_min': 61.07},
#  'name': 'Yuancheng',
#  'sys': {'country': 'CN', 'sunrise': 1601332938, 'sunset': 1601375753},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 113, 'speed': 9.71}}
# {'base': 'stations',
#  'clouds': {'all': 56},
#  'cod': 200,
#  'coord': {'lat': 69.38, 'lon': 178.42},
#  'dt': 1601387032,
#  'id': 2123814,
#  'main': {'feels_like': 23.32,
#           'grnd_level': 1010,
#           'humidity': 86,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 33.08,
#           'temp_max': 33.08,
#           'temp_min': 33.08},
#  'name': 'Leningradskiy',
#  'sys': {'country': 'RU', 'sunrise': 1601403389, 'sunset': 1601444166},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 148, 'speed': 10.31}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 31.67, 'lon': 34.57},
#  'dt': 1601387033,
#  'id': 295620,
#  'main': {'feels_like': 91.13,
#           'humidity': 66,
#           'pressure': 1011,
#           'temp': 86.59,
#           'temp_max': 88,
#           'temp_min': 84},
#  'name': 'Ashquelon',
#  'sys': {'country': 'IL',
#          'id': 6845,
#          'sunrise': 1601350457,
#          'sunset': 1601393371,
#          'type': 1},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 300, 'speed': 9.17}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 5.41, 'lon': 100.34},
#  'dt': 1601386978,
#  'id': 1735106,
#  'main': {'feels_like': 91.56,
#           'humidity': 79,
#           'pressure': 1008,
#           'temp': 83.25,
#           'temp_max': 84.2,
#           'temp_min': 82},
#  'name': 'George Town',
#  'sys': {'country': 'MY',
#          'id': 9429,
#          'sunrise': 1601334389,
#          'sunset': 1601377877,
#          'type': 1},
#  'timezone': 28800,
#  'visibility': 8000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 200, 'speed': 4.7}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 56.2, 'lon': 40.53},
#  'dt': 1601387033,
#  'id': 575609,
#  'main': {'feels_like': 50.05,
#           'grnd_level': 1012,
#           'humidity': 55,
#           'pressure': 1028,
#           'sea_level': 1028,
#           'temp': 56.61,
#           'temp_max': 56.61,
#           'temp_min': 56.61},
#  'name': 'Bogolyubovo',
#  'sys': {'country': 'RU', 'sunrise': 1601349437, 'sunset': 1601391530},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 148, 'speed': 7.92}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -9.8, 'lon': -139.03},
#  'dt': 1601387034,
#  'id': 4020109,
#  'main': {'feels_like': 72.84,
#           'grnd_level': 1009,
#           'humidity': 74,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 77.27,
#           'temp_max': 77.27,
#           'temp_min': 77.27},
#  'name': 'Atuona',
#  'sys': {'country': 'PF', 'sunrise': 1601391652, 'sunset': 1601435484},
#  'timezone': -34200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 100, 'speed': 19.95}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 22.28, 'lon': 113.57},
#  'dt': 1601387034,
#  'id': 1790437,
#  'main': {'feels_like': 87.78,
#           'humidity': 83,
#           'pressure': 1008,
#           'temp': 82.27,
#           'temp_max': 82.4,
#           'temp_min': 82},
#  'name': 'Zhuhai',
#  'rain': {'1h': 0.17},
#  'sys': {'country': 'CN',
#          'id': 9204,
#          'sunrise': 1601331385,
#          'sunset': 1601374531,
#          'type': 1},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 130, 'speed': 10.29}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 69.45, 'lon': -133.04},
#  'dt': 1601387035,
#  'id': 6170031,
#  'main': {'feels_like': 26.51,
#           'humidity': 98,
#           'pressure': 1016,
#           'temp': 33.8,
#           'temp_max': 33.8,
#           'temp_min': 33.8},
#  'name': 'Tuktoyaktuk',
#  'sys': {'country': 'CA',
#          'id': 942,
#          'sunrise': 1601391713,
#          'sunset': 1601432549,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 340, 'speed': 6.93}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -37.83, 'lon': 140.77},
#  'dt': 1601387035,
#  'id': 2156643,
#  'main': {'feels_like': 50.76,
#           'humidity': 87,
#           'pressure': 1012,
#           'temp': 55.4,
#           'temp_max': 55.4,
#           'temp_min': 55.4},
#  'name': 'Mount Gambier',
#  'rain': {'1h': 1.83},
#  'sys': {'country': 'AU',
#          'id': 9560,
#          'sunrise': 1601324125,
#          'sunset': 1601368739,
#          'type': 1},
#  'timezone': 34200,
#  'visibility': 10000,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10n',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 360, 'speed': 9.17}}
# {'base': 'stations',
#  'clouds': {'all': 67},
#  'cod': 200,
#  'coord': {'lat': 25.52, 'lon': 90.22},
#  'dt': 1601387036,
#  'id': 1254046,
#  'main': {'feels_like': 84.74,
#           'grnd_level': 961,
#           'humidity': 90,
#           'pressure': 1004,
#           'sea_level': 1004,
#           'temp': 76.55,
#           'temp_max': 76.55,
#           'temp_min': 76.55},
#  'name': 'Tura',
#  'sys': {'country': 'IN', 'sunrise': 1601337025, 'sunset': 1601380097},
#  'timezone': 19800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 55, 'speed': 2.21}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -0.74, 'lon': -90.35},
#  'dt': 1601387036,
#  'id': 3652764,
#  'main': {'feels_like': 70.16,
#           'humidity': 92,
#           'pressure': 1013,
#           'temp': 68,
#           'temp_max': 68,
#           'temp_min': 68},
#  'name': 'Puerto Ayora',
#  'sys': {'country': 'EC',
#          'id': 2005652,
#          'sunrise': 1601380080,
#          'sunset': 1601423695,
#          'type': 3},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 198, 'gust': 14, 'speed': 5.99}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -23.12, 'lon': -134.97},
#  'dt': 1601387037,
#  'id': 4030556,
#  'main': {'feels_like': 63.39,
#           'grnd_level': 1016,
#           'humidity': 80,
#           'pressure': 1019,
#           'sea_level': 1019,
#           'temp': 70.12,
#           'temp_max': 70.12,
#           'temp_min': 70.12},
#  'name': 'Rikitea',
#  'sys': {'country': 'PF', 'sunrise': 1601390497, 'sunset': 1601434691},
#  'timezone': -32400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 137, 'speed': 20.33}}
# {'base': 'stations',
#  'clouds': {'all': 2},
#  'cod': 200,
#  'coord': {'lat': -33.59, 'lon': 26.89},
#  'dt': 1601387037,
#  'id': 964432,
#  'main': {'feels_like': 49.91,
#           'grnd_level': 1022,
#           'humidity': 63,
#           'pressure': 1024,
#           'sea_level': 1024,
#           'temp': 62.19,
#           'temp_max': 62.19,
#           'temp_min': 62.19},
#  'name': 'Port Alfred',
#  'sys': {'country': 'ZA', 'sunrise': 1601351509, 'sunset': 1601396004},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 218, 'speed': 21.68}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -21.2, 'lon': -175.2},
#  'dt': 1601387038,
#  'id': 4032243,
#  'main': {'feels_like': 79.56,
#           'humidity': 100,
#           'pressure': 1014,
#           'temp': 73.4,
#           'temp_max': 73.4,
#           'temp_min': 73.4},
#  'name': 'Vaini',
#  'sys': {'country': 'TO',
#          'id': 7285,
#          'sunrise': 1601486518,
#          'sunset': 1601530735,
#          'type': 1},
#  'timezone': 46800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 70, 'speed': 5.82}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -34.53, 'lon': 20.04},
#  'dt': 1601387038,
#  'id': 1015776,
#  'main': {'feels_like': 53.01,
#           'humidity': 45,
#           'pressure': 1025,
#           'temp': 64.4,
#           'temp_max': 64.4,
#           'temp_min': 64.4},
#  'name': 'Bredasdorp',
#  'sys': {'country': 'ZA',
#          'id': 1966,
#          'sunrise': 1601353134,
#          'sunset': 1601397666,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 210, 'speed': 17.22}}
# {'base': 'stations',
#  'clouds': {'all': 57},
#  'cod': 200,
#  'coord': {'lat': -2.02, 'lon': 147.27},
#  'dt': 1601387039,
#  'id': 2092164,
#  'main': {'feels_like': 87.03,
#           'grnd_level': 1008,
#           'humidity': 76,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 82.18,
#           'temp_max': 82.18,
#           'temp_min': 82.18},
#  'name': 'Lorengau',
#  'sys': {'country': 'PG', 'sunrise': 1601323052, 'sunset': 1601366692},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 114, 'speed': 8.61}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 39.18, 'lon': -84.53},
#  'dt': 1601387039,
#  'id': 4513583,
#  'main': {'feels_like': 50.38,
#           'humidity': 100,
#           'pressure': 1015,
#           'temp': 51.73,
#           'temp_max': 53.01,
#           'temp_min': 50},
#  'name': 'Hamilton',
#  'sys': {'country': 'US',
#          'id': 4776,
#          'sunrise': 1601379158,
#          'sunset': 1601421824,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 289, 'speed': 3.4}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 63.84, 'lon': -22.43},
#  'dt': 1601387040,
#  'id': 3416888,
#  'main': {'feels_like': 36.41,
#           'humidity': 81,
#           'pressure': 991,
#           'temp': 44.6,
#           'temp_max': 44.6,
#           'temp_min': 44.6},
#  'name': 'Grindavik',
#  'sys': {'country': 'IS',
#          'id': 90,
#          'sunrise': 1601364815,
#          'sunset': 1601406366,
#          'type': 1},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'shower rain',
#               'icon': '09d',
#               'id': 521,
#               'main': 'Rain'}],
#  'wind': {'deg': 150, 'speed': 10.29}}
# {'base': 'stations',
#  'clouds': {'all': 24},
#  'cod': 200,
#  'coord': {'lat': 13.6, 'lon': 26.69},
#  'dt': 1601387040,
#  'id': 364933,
#  'main': {'feels_like': 97.27,
#           'grnd_level': 941,
#           'humidity': 22,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 99.32,
#           'temp_max': 99.32,
#           'temp_min': 99.32},
#  'name': 'Umm Kaddadah',
#  'sys': {'country': 'SD', 'sunrise': 1601352148, 'sunset': 1601395461},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 117, 'speed': 5.68}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 40.8, 'lon': -124.16},
#  'dt': 1601386936,
#  'id': 5563397,
#  'main': {'feels_like': 51.33,
#           'humidity': 58,
#           'pressure': 1015,
#           'temp': 59.07,
#           'temp_max': 62.01,
#           'temp_min': 55.4},
#  'name': 'Eureka',
#  'sys': {'country': 'US',
#          'id': 4127,
#          'sunrise': 1601388700,
#          'sunset': 1601431300,
#          'type': 1},
#  'timezone': -25200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 130, 'speed': 11.41}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 19.73, 'lon': -155.09},
#  'dt': 1601387042,
#  'id': 5855927,
#  'main': {'feels_like': 67.62,
#           'humidity': 60,
#           'pressure': 1013,
#           'temp': 69.39,
#           'temp_max': 71.6,
#           'temp_min': 66},
#  'name': 'Hilo',
#  'sys': {'country': 'US',
#          'id': 7881,
#          'sunrise': 1601395847,
#          'sunset': 1601438996,
#          'type': 1},
#  'timezone': -36000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 240, 'speed': 5.82}}
# {'base': 'stations',
#  'clouds': {'all': 60},
#  'cod': 200,
#  'coord': {'lat': -20.58, 'lon': 48.53},
#  'dt': 1601387042,
#  'id': 1058080,
#  'main': {'feels_like': 75.24,
#           'grnd_level': 1017,
#           'humidity': 69,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 75.25,
#           'temp_max': 75.25,
#           'temp_min': 75.25},
#  'name': 'Nosy Varika',
#  'sys': {'country': 'MG', 'sunrise': 1601346523, 'sunset': 1601390606},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 68, 'speed': 8.93}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -42.88, 'lon': 147.33},
#  'dt': 1601386850,
#  'id': 2163355,
#  'main': {'feels_like': 44.73,
#           'humidity': 62,
#           'pressure': 1015,
#           'temp': 52.2,
#           'temp_max': 53.01,
#           'temp_min': 51.8},
#  'name': 'Hobart',
#  'sys': {'country': 'AU',
#          'id': 9545,
#          'sunrise': 1601322444,
#          'sunset': 1601367272,
#          'type': 1},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 350, 'speed': 9.17}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 36.43, 'lon': -99.39},
#  'dt': 1601387043,
#  'id': 4556050,
#  'main': {'feels_like': 33.64,
#           'humidity': 56,
#           'pressure': 1024,
#           'temp': 42.89,
#           'temp_max': 46,
#           'temp_min': 39.2},
#  'name': 'Woodward',
#  'sys': {'country': 'US',
#          'id': 6275,
#          'sunrise': 1601382686,
#          'sunset': 1601425427,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 220, 'speed': 9.17}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 17.02, 'lon': 54.09},
#  'dt': 1601387043,
#  'id': 286621,
#  'main': {'feels_like': 83.95,
#           'humidity': 74,
#           'pressure': 1008,
#           'temp': 82.4,
#           'temp_max': 82.4,
#           'temp_min': 82.4},
#  'name': 'Salalah',
#  'sys': {'country': 'OM',
#          'id': 7562,
#          'sunrise': 1601345607,
#          'sunset': 1601388853,
#          'type': 1},
#  'timezone': 14400,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 200, 'speed': 13.87}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -35.33, 'lon': -72.42},
#  'dt': 1601387044,
#  'id': 3893726,
#  'main': {'feels_like': 43.07,
#           'grnd_level': 1015,
#           'humidity': 76,
#           'pressure': 1018,
#           'sea_level': 1018,
#           'temp': 51.8,
#           'temp_max': 51.8,
#           'temp_min': 51.8},
#  'name': 'Constitución',
#  'sys': {'country': 'CL', 'sunrise': 1601375287, 'sunset': 1601419884},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 0, 'speed': 13.22}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -27.46, 'lon': -58.98},
#  'dt': 1601387044,
#  'id': 3429577,
#  'main': {'feels_like': 73.81,
#           'humidity': 46,
#           'pressure': 1012,
#           'temp': 77.43,
#           'temp_max': 80.01,
#           'temp_min': 73.4},
#  'name': 'Resistencia',
#  'sys': {'country': 'AR',
#          'id': 8257,
#          'sunrise': 1601372205,
#          'sunset': 1601416516,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 8000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 80, 'speed': 9.17}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -53.15, 'lon': -70.92},
#  'dt': 1601386941,
#  'id': 3874787,
#  'main': {'feels_like': 14.25,
#           'humidity': 64,
#           'pressure': 993,
#           'temp': 33.82,
#           'temp_max': 35.6,
#           'temp_min': 32},
#  'name': 'Punta Arenas',
#  'sys': {'country': 'CL',
#          'id': 8487,
#          'sunrise': 1601374438,
#          'sunset': 1601420013,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 310, 'speed': 26.4}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 22.57, 'lon': 59.53},
#  'dt': 1601387045,
#  'id': 286245,
#  'main': {'feels_like': 90.7,
#           'grnd_level': 1006,
#           'humidity': 50,
#           'pressure': 1006,
#           'sea_level': 1006,
#           'temp': 87.46,
#           'temp_max': 87.46,
#           'temp_min': 87.46},
#  'name': 'Sur',
#  'sys': {'country': 'OM', 'sunrise': 1601344361, 'sunset': 1601387489},
#  'timezone': 14400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 184, 'speed': 4.83}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 41.14, 'lon': -73.36},
#  'dt': 1601386923,
#  'id': 4845585,
#  'main': {'feels_like': 71.28,
#           'humidity': 88,
#           'pressure': 1013,
#           'temp': 68.65,
#           'temp_max': 70,
#           'temp_min': 68},
#  'name': 'Westport',
#  'sys': {'country': 'US',
#          'id': 3409,
#          'sunrise': 1601376505,
#          'sunset': 1601419116,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 140, 'speed': 4.7}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -34, 'lon': 24.73},
#  'dt': 1601387045,
#  'id': 986717,
#  'main': {'feels_like': 56.39,
#           'humidity': 48,
#           'pressure': 1025,
#           'temp': 64,
#           'temp_max': 64,
#           'temp_min': 64},
#  'name': 'Kruisfontein',
#  'sys': {'country': 'ZA',
#          'id': 2035063,
#          'sunrise': 1601352019,
#          'sunset': 1601396530,
#          'type': 3},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 221, 'gust': 21, 'speed': 11.01}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 62.88, 'lon': 152.43},
#  'dt': 1601387046,
#  'id': 2121373,
#  'main': {'feels_like': 34.74,
#           'grnd_level': 980,
#           'humidity': 64,
#           'pressure': 1004,
#           'sea_level': 1004,
#           'temp': 42.22,
#           'temp_max': 42.22,
#           'temp_min': 42.22},
#  'name': 'Seymchan',
#  'sys': {'country': 'RU', 'sunrise': 1601409295, 'sunset': 1601450733},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 162, 'speed': 6.67}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 18.74, 'lon': 7.39},
#  'dt': 1601387000,
#  'id': 2447513,
#  'main': {'feels_like': 99.45,
#           'grnd_level': 962,
#           'humidity': 7,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 106.56,
#           'temp_max': 106.56,
#           'temp_min': 106.56},
#  'name': 'Arlit',
#  'sys': {'country': 'NE', 'sunrise': 1601356835, 'sunset': 1601400036},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 27, 'speed': 5.68}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -24.87, 'lon': 113.63},
#  'dt': 1601387047,
#  'id': 2074865,
#  'main': {'feels_like': 61.77,
#           'humidity': 77,
#           'pressure': 1018,
#           'temp': 68,
#           'temp_max': 68,
#           'temp_min': 68},
#  'name': 'Carnarvon',
#  'sys': {'country': 'AU',
#          'id': 9505,
#          'sunrise': 1601330850,
#          'sunset': 1601375038,
#          'type': 1},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 180, 'speed': 17.22}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 34.64, 'lon': -99.33},
#  'dt': 1601387047,
#  'id': 4529292,
#  'main': {'feels_like': 39.31,
#           'humidity': 70,
#           'pressure': 1024,
#           'temp': 45.48,
#           'temp_max': 48.2,
#           'temp_min': 42.8},
#  'name': 'Altus',
#  'sys': {'country': 'US',
#          'id': 3369,
#          'sunrise': 1601382647,
#          'sunset': 1601425438,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 340, 'speed': 5.82}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 14.69, 'lon': -17.44},
#  'dt': 1601386837,
#  'id': 2253354,
#  'main': {'feels_like': 91.4,
#           'humidity': 70,
#           'pressure': 1013,
#           'temp': 87.8,
#           'temp_max': 87.8,
#           'temp_min': 87.8},
#  'name': 'Dakar',
#  'sys': {'country': 'SN',
#          'id': 2419,
#          'sunrise': 1601362751,
#          'sunset': 1601406035,
#          'type': 1},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 360, 'speed': 13.87}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -15.2, 'lon': 12.15},
#  'dt': 1601387048,
#  'id': 3347019,
#  'main': {'feels_like': 68.63,
#           'humidity': 68,
#           'pressure': 1011,
#           'temp': 71.6,
#           'temp_max': 71.6,
#           'temp_min': 71.6},
#  'name': 'Mossamedes',
#  'sys': {'country': 'AO',
#          'id': 2155,
#          'sunrise': 1601355319,
#          'sunset': 1601399268,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 260, 'speed': 11.41}}
# {'base': 'stations',
#  'clouds': {'all': 91},
#  'cod': 200,
#  'coord': {'lat': -46.6, 'lon': 168.33},
#  'dt': 1601387048,
#  'id': 2206939,
#  'main': {'feels_like': 31.33,
#           'humidity': 84,
#           'pressure': 1012,
#           'temp': 39.99,
#           'temp_max': 39.99,
#           'temp_min': 39.99},
#  'name': 'Bluff',
#  'sys': {'country': 'NZ',
#          'id': 2008959,
#          'sunrise': 1601403598,
#          'sunset': 1601448799,
#          'type': 3},
#  'timezone': 46800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 222, 'gust': 18.99, 'speed': 10}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 39.27, 'lon': 141.88},
#  'dt': 1601386927,
#  'id': 2112444,
#  'main': {'feels_like': 58.03,
#           'grnd_level': 1011,
#           'humidity': 68,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 58.78,
#           'temp_max': 58.78,
#           'temp_min': 58.78},
#  'name': 'Kamaishi',
#  'sys': {'country': 'JP', 'sunrise': 1601324786, 'sunset': 1601367545},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 293, 'speed': 0.67}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 71.69, 'lon': 128.87},
#  'dt': 1601387049,
#  'id': 2015306,
#  'main': {'feels_like': 26.44,
#           'grnd_level': 993,
#           'humidity': 96,
#           'pressure': 997,
#           'sea_level': 997,
#           'temp': 32.47,
#           'temp_max': 32.47,
#           'temp_min': 32.47},
#  'name': 'Tiksi',
#  'sys': {'country': 'RU', 'sunrise': 1601328830, 'sunset': 1601369745},
#  'timezone': 32400,
#  'visibility': 912,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 298, 'speed': 4.21}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 26.62, 'lon': -78.28},
#  'dt': 1601387049,
#  'id': 3572189,
#  'main': {'feels_like': 91.83,
#           'humidity': 79,
#           'pressure': 1014,
#           'temp': 84.2,
#           'temp_max': 84.2,
#           'temp_min': 84.2},
#  'name': 'High Rock',
#  'sys': {'country': 'BS',
#          'id': 7260,
#          'sunrise': 1601377490,
#          'sunset': 1601420493,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 160, 'speed': 6.93}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 38.42, 'lon': -121.42},
#  'dt': 1601387049,
#  'id': 5364271,
#  'main': {'feels_like': 62.13,
#           'humidity': 72,
#           'pressure': 1015,
#           'temp': 62.38,
#           'temp_max': 66,
#           'temp_min': 60.8},
#  'name': 'Laguna',
#  'sys': {'country': 'US',
#          'id': 5769,
#          'sunrise': 1601388006,
#          'sunset': 1601430680,
#          'type': 1},
#  'timezone': -25200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 312, 'speed': 2.24}}
# {'base': 'stations',
#  'clouds': {'all': 98},
#  'cod': 200,
#  'coord': {'lat': 71.92, 'lon': 114.08},
#  'dt': 1601387050,
#  'id': 2017155,
#  'main': {'feels_like': 18.54,
#           'grnd_level': 1004,
#           'humidity': 94,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 27.75,
#           'temp_max': 27.75,
#           'temp_min': 27.75},
#  'name': 'Saskylakh',
#  'sys': {'country': 'RU', 'sunrise': 1601332407, 'sunset': 1601373265},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 307, 'speed': 8.66}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 57.79, 'lon': -152.41},
#  'dt': 1601387050,
#  'id': 5866583,
#  'main': {'feels_like': 32.58,
#           'humidity': 93,
#           'pressure': 1015,
#           'temp': 39.2,
#           'temp_max': 39.2,
#           'temp_min': 39.2},
#  'name': 'Saint Paul Harbor',
#  'sys': {'country': 'US',
#          'id': 7668,
#          'sunrise': 1601395853,
#          'sunset': 1601437704,
#          'type': 1},
#  'timezone': -28800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 290, 'speed': 6.93}}
# {'cod': '404', 'message': 'city not found'}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 43.2, 'lon': 51.65},
#  'dt': 1601387051,
#  'id': 609919,
#  'main': {'feels_like': 59.85,
#           'grnd_level': 1029,
#           'humidity': 30,
#           'pressure': 1025,
#           'sea_level': 1025,
#           'temp': 65.64,
#           'temp_max': 65.64,
#           'temp_min': 65.64},
#  'name': 'Quryq',
#  'sys': {'country': 'KZ', 'sunrise': 1601346513, 'sunset': 1601389119},
#  'timezone': 18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 117, 'speed': 4.32}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -20.73, 'lon': -42.03},
#  'dt': 1601387052,
#  'id': 3467012,
#  'main': {'feels_like': 91.81,
#           'grnd_level': 965,
#           'humidity': 40,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 90.03,
#           'temp_max': 90.03,
#           'temp_min': 90.03},
#  'name': 'Carangola',
#  'sys': {'country': 'BR', 'sunrise': 1601368241, 'sunset': 1601412346},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 168, 'speed': 4.32}}
# {'base': 'stations',
#  'clouds': {'all': 47},
#  'cod': 200,
#  'coord': {'lat': 43.87, 'lon': 25.7},
#  'dt': 1601387052,
#  'id': 676981,
#  'main': {'feels_like': 66.2,
#           'humidity': 39,
#           'pressure': 1004,
#           'temp': 71.76,
#           'temp_max': 72,
#           'temp_min': 71.01},
#  'name': 'Gogoşari',
#  'sys': {'country': 'RO',
#          'id': 2013364,
#          'sunrise': 1601352756,
#          'sunset': 1601395328,
#          'type': 3},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 283, 'gust': 14, 'speed': 8.01}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 54.77, 'lon': -101.86},
#  'dt': 1601387052,
#  'id': 5954718,
#  'main': {'feels_like': 40.21,
#           'humidity': 87,
#           'pressure': 1004,
#           'temp': 46.4,
#           'temp_max': 46.4,
#           'temp_min': 46.4},
#  'name': 'Flin Flon',
#  'sys': {'country': 'CA',
#          'id': 782,
#          'sunrise': 1601383621,
#          'sunset': 1601425678,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 270, 'speed': 8.05}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -20.73, 'lon': 139.5},
#  'dt': 1601387053,
#  'id': 2065594,
#  'main': {'feels_like': 59.63,
#           'humidity': 29,
#           'pressure': 1013,
#           'temp': 66.2,
#           'temp_max': 66.2,
#           'temp_min': 66.2},
#  'name': 'Mount Isa',
#  'sys': {'country': 'AU',
#          'id': 9495,
#          'sunrise': 1601324702,
#          'sunset': 1601368771,
#          'type': 1},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 217, 'speed': 5.57}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 42.1, 'lon': -79.24},
#  'dt': 1601387053,
#  'id': 5122534,
#  'main': {'feels_like': 50.36,
#           'humidity': 93,
#           'pressure': 1012,
#           'temp': 55.17,
#           'temp_max': 55.99,
#           'temp_min': 53.6},
#  'name': 'Jamestown',
#  'sys': {'country': 'US',
#          'id': 4588,
#          'sunrise': 1601377933,
#          'sunset': 1601420511,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 220, 'speed': 10.29}}
# {'base': 'stations',
#  'clouds': {'all': 97},
#  'cod': 200,
#  'coord': {'lat': -33.65, 'lon': 115.33},
#  'dt': 1601387054,
#  'id': 2075265,
#  'main': {'feels_like': 51.6,
#           'humidity': 75,
#           'pressure': 1012,
#           'temp': 57.42,
#           'temp_max': 60.01,
#           'temp_min': 55},
#  'name': 'Busselton',
#  'sys': {'country': 'AU',
#          'id': 2011706,
#          'sunrise': 1601330303,
#          'sunset': 1601374769,
#          'type': 3},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 253, 'speed': 10.27}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -54.8, 'lon': -68.3},
#  'dt': 1601387054,
#  'id': 3833367,
#  'main': {'feels_like': 19.15,
#           'humidity': 74,
#           'pressure': 991,
#           'temp': 33.8,
#           'temp_max': 33.8,
#           'temp_min': 33.8},
#  'name': 'Ushuaia',
#  'sys': {'country': 'AR',
#          'id': 8303,
#          'sunrise': 1601373743,
#          'sunset': 1601419450,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 360, 'speed': 18.34}}
# {'base': 'stations',
#  'clouds': {'all': 50},
#  'cod': 200,
#  'coord': {'lat': -8.93, 'lon': 125.41},
#  'dt': 1601387055,
#  'id': 1651810,
#  'main': {'feels_like': 60.78,
#           'grnd_level': 856,
#           'humidity': 94,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 59.79,
#           'temp_max': 59.79,
#           'temp_min': 59.79},
#  'name': 'Airai',
#  'sys': {'country': 'TL', 'sunrise': 1601328223, 'sunset': 1601372012},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 119, 'speed': 2.8}}
# {'base': 'stations',
#  'clouds': {'all': 89},
#  'cod': 200,
#  'coord': {'lat': 3.07, 'lon': 172.79},
#  'dt': 1601387055,
#  'id': 2110227,
#  'main': {'feels_like': 82.11,
#           'grnd_level': 1006,
#           'humidity': 77,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 81.72,
#           'temp_max': 81.72,
#           'temp_min': 81.72},
#  'name': 'Butaritari',
#  'sys': {'country': 'KI', 'sunrise': 1601403365, 'sunset': 1601446892},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 132, 'speed': 16.44}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -8.19, 'lon': 114.97},
#  'dt': 1601387055,
#  'id': 1650232,
#  'main': {'feels_like': 91.15,
#           'humidity': 100,
#           'pressure': 1011,
#           'temp': 82.4,
#           'temp_max': 82.4,
#           'temp_min': 82.4},
#  'name': 'Banjar',
#  'sys': {'country': 'ID',
#          'id': 9333,
#          'sunrise': 1601330736,
#          'sunset': 1601374509,
#          'type': 1},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 150, 'speed': 11.41}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 14.92, 'lon': -23.51},
#  'dt': 1601386873,
#  'id': 3374333,
#  'main': {'feels_like': 85.3,
#           'humidity': 62,
#           'pressure': 1015,
#           'temp': 86,
#           'temp_max': 86,
#           'temp_min': 86},
#  'name': 'Praia',
#  'sys': {'country': 'CV',
#          'id': 2462,
#          'sunrise': 1601364210,
#          'sunset': 1601407489,
#          'type': 1},
#  'timezone': -3600,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 10, 'speed': 16.11}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -33.93, 'lon': 18.42},
#  'dt': 1601386801,
#  'id': 3369157,
#  'main': {'feels_like': 49.51,
#           'humidity': 45,
#           'pressure': 1025,
#           'temp': 62.53,
#           'temp_max': 63,
#           'temp_min': 62.01},
#  'name': 'Cape Town',
#  'sys': {'country': 'ZA',
#          'id': 1899,
#          'sunrise': 1601353534,
#          'sunset': 1601398044,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 190, 'speed': 19.46}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 11.67, 'lon': 92.75},
#  'dt': 1601387056,
#  'id': 1259385,
#  'main': {'feels_like': 80.58,
#           'grnd_level': 1008,
#           'humidity': 80,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 81.14,
#           'temp_max': 81.14,
#           'temp_min': 81.14},
#  'name': 'Port Blair',
#  'sys': {'country': 'IN', 'sunrise': 1601336274, 'sunset': 1601379634},
#  'timezone': 19800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 239, 'speed': 18.72}}
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': -0.6, 'lon': 73.08},
#  'dt': 1601387057,
#  'id': 1282256,
#  'main': {'feels_like': 87.28,
#           'grnd_level': 1010,
#           'humidity': 70,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 83.88,
#           'temp_max': 83.88,
#           'temp_min': 83.88},
#  'name': 'Hithadhoo',
#  'sys': {'country': 'MV', 'sunrise': 1601340868, 'sunset': 1601384479},
#  'timezone': 18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 192, 'speed': 10.36}}
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': 35.51, 'lon': 27.21},
#  'dt': 1601387057,
#  'id': 260895,
#  'main': {'feels_like': 74.93,
#           'humidity': 54,
#           'pressure': 1013,
#           'temp': 84.2,
#           'temp_max': 84.2,
#           'temp_min': 84.2},
#  'name': 'Karpathos',
#  'sys': {'country': 'GR',
#          'id': 6620,
#          'sunrise': 1601352273,
#          'sunset': 1601395087,
#          'type': 1},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 310, 'gust': 38.03, 'speed': 26.4}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 50.57, 'lon': 116.25},
#  'dt': 1601387057,
#  'id': 2016735,
#  'main': {'feels_like': 32.76,
#           'grnd_level': 910,
#           'humidity': 74,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 38.55,
#           'temp_max': 38.55,
#           'temp_min': 38.55},
#  'name': 'Sherlovaya Gora',
#  'sys': {'country': 'RU', 'sunrise': 1601331120, 'sunset': 1601373511},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 176, 'speed': 3.69}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 57},
#  'cod': 200,
#  'coord': {'lat': -24.79, 'lon': -50.01},
#  'dt': 1601387058,
#  'id': 3466704,
#  'main': {'feels_like': 78.35,
#           'grnd_level': 909,
#           'humidity': 64,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 76.87,
#           'temp_max': 76.87,
#           'temp_min': 76.87},
#  'name': 'Castro',
#  'sys': {'country': 'BR', 'sunrise': 1601370096, 'sunset': 1601414321},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 49, 'speed': 5.82}}
# {'base': 'stations',
#  'clouds': {'all': 2},
#  'cod': 200,
#  'coord': {'lat': 5.35, 'lon': 48.53},
#  'dt': 1601387059,
#  'id': 57000,
#  'main': {'feels_like': 77.13,
#           'grnd_level': 1008,
#           'humidity': 77,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 79.65,
#           'temp_max': 79.65,
#           'temp_min': 79.65},
#  'name': 'Hobyo',
#  'rain': {'1h': 0.24},
#  'sys': {'country': 'SO', 'sunrise': 1601346821, 'sunset': 1601390308},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 181, 'speed': 19.66}}
# {'base': 'stations',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': 73.51, 'lon': 80.55},
#  'dt': 1601387059,
#  'id': 1507390,
#  'main': {'feels_like': 22.98,
#           'grnd_level': 1007,
#           'humidity': 83,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 35.87,
#           'temp_max': 35.87,
#           'temp_min': 35.87},
#  'name': 'Dikson',
#  'sys': {'country': 'RU', 'sunrise': 1601340608, 'sunset': 1601381154},
#  'timezone': 25200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 26, 'speed': 16.35}}
# {'base': 'stations',
#  'clouds': {'all': 66},
#  'cod': 200,
#  'coord': {'lat': 36.62, 'lon': 101.77},
#  'dt': 1601387059,
#  'id': 1788852,
#  'main': {'feels_like': 51.6,
#           'grnd_level': 779,
#           'humidity': 52,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 57.63,
#           'temp_max': 57.63,
#           'temp_min': 57.63},
#  'name': 'Xining',
#  'sys': {'country': 'CN', 'sunrise': 1601334383, 'sunset': 1601377196},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 124, 'speed': 6.82}}
# {'base': 'stations',
#  'clouds': {'all': 2},
#  'cod': 200,
#  'coord': {'lat': -3.8, 'lon': 102.27},
#  'dt': 1601387060,
#  'id': 1649150,
#  'main': {'feels_like': 80.83,
#           'grnd_level': 1008,
#           'humidity': 87,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 78.28,
#           'temp_max': 78.28,
#           'temp_min': 78.28},
#  'name': 'Bengkulu',
#  'sys': {'country': 'ID', 'sunrise': 1601333830, 'sunset': 1601377509},
#  'timezone': 25200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 130, 'speed': 12.91}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 69.7, 'lon': 170.31},
#  'dt': 1601387060,
#  'id': 2122090,
#  'main': {'feels_like': 25.65,
#           'grnd_level': 1001,
#           'humidity': 72,
#           'pressure': 1006,
#           'sea_level': 1006,
#           'temp': 39.43,
#           'temp_max': 39.43,
#           'temp_min': 39.43},
#  'name': 'Pevek',
#  'sys': {'country': 'RU', 'sunrise': 1601405362, 'sunset': 1601446085},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 156, 'speed': 17.92}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 82},
#  'cod': 200,
#  'coord': {'lat': 11.33, 'lon': -14.93},
#  'dt': 1601387061,
#  'id': 2370473,
#  'main': {'feels_like': 99.46,
#           'grnd_level': 1007,
#           'humidity': 61,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 90.23,
#           'temp_max': 90.23,
#           'temp_min': 90.23},
#  'name': 'Quebo',
#  'sys': {'country': 'GW', 'sunrise': 1601362113, 'sunset': 1601405469},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 349, 'speed': 1.9}}
# {'base': 'stations',
#  'clouds': {'all': 13},
#  'cod': 200,
#  'coord': {'lat': 4.38, 'lon': -7.72},
#  'dt': 1601387062,
#  'id': 2276492,
#  'main': {'feels_like': 83.53,
#           'grnd_level': 1011,
#           'humidity': 83,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 80.08,
#           'temp_max': 80.08,
# ...
#           'temp': 64.4,
#           'temp_max': 64.4,
#           'temp_min': 64.4},
#  'name': 'Talara',
#  'sys': {'country': 'PE',
#          'id': 8685,
#          'sunrise': 1601377857,
#          'sunset': 1601421560,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 140, 'speed': 19.46}}
# {'base': 'stations',
#  'clouds': {'all': 95},
#  'cod': 200,
#  'coord': {'lat': -19.98, 'lon': 57.61},
#  'dt': 1601387274,
#  'id': 934649,
#  'main': {'feels_like': 78.3,
#           'humidity': 81,
#           'pressure': 1019,
#           'temp': 73.99,
#           'temp_max': 73.99,
#           'temp_min': 73.99},
#  'name': 'Cap Malheureux',
#  'rain': {'1h': 0.51},
#  'sys': {'country': 'MU',
#          'id': 2002134,
#          'sunrise': 1601344353,
#          'sunset': 1601388418,
#          'type': 3},
#  'timezone': 14400,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 98, 'gust': 8.99, 'speed': 4}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 33.08, 'lon': -16.33},
#  'dt': 1601387274,
#  'id': 2270385,
#  'main': {'feels_like': 69.67,
#           'humidity': 64,
#           'pressure': 1020,
#           'temp': 73.4,
#           'temp_max': 73.4,
#           'temp_min': 73.4},
#  'name': 'Camacha',
#  'sys': {'country': 'PT',
#          'id': 6902,
#          'sunrise': 1601362696,
#          'sunset': 1601405558,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 20, 'speed': 12.75}}
# {'base': 'stations',
#  'clouds': {'all': 91},
#  'cod': 200,
#  'coord': {'lat': 49.27, 'lon': -101},
#  'dt': 1601387275,
#  'id': 6071900,
#  'main': {'feels_like': 42.06,
#           'humidity': 88,
#           'pressure': 1009,
#           'temp': 46,
#           'temp_max': 46,
#           'temp_min': 46},
#  'name': 'Melita',
#  'sys': {'country': 'CA',
#          'id': 2033645,
#          'sunrise': 1601383289,
#          'sunset': 1601425597,
#          'type': 3},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 299, 'gust': 7, 'speed': 4}}
# {'base': 'stations',
#  'clouds': {'all': 9},
#  'cod': 200,
#  'coord': {'lat': 64.9, 'lon': 45.76},
#  'dt': 1601387275,
#  'id': 535839,
#  'main': {'feels_like': 47.26,
#           'grnd_level': 1022,
#           'humidity': 73,
#           'pressure': 1027,
#           'sea_level': 1027,
#           'temp': 51.39,
#           'temp_max': 51.39,
#           'temp_min': 51.39},
#  'name': 'Leshukonskoye',
#  'sys': {'country': 'RU', 'sunrise': 1601348460, 'sunset': 1601389998},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 192, 'speed': 4.47}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 61.38, 'lon': 152.75},
#  'dt': 1601387275,
#  'id': 2120769,
#  'main': {'feels_like': 31.71,
#           'grnd_level': 945,
#           'humidity': 81,
#           'pressure': 1006,
#           'sea_level': 1006,
#           'temp': 38.37,
#           'temp_max': 38.37,
#           'temp_min': 38.37},
#  'name': 'Talaya',
#  'sys': {'country': 'RU', 'sunrise': 1601409158, 'sunset': 1601450716},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 171, 'speed': 5.77}}
# {'base': 'stations',
#  'clouds': {'all': 96},
#  'cod': 200,
#  'coord': {'lat': 0.6, 'lon': -80.03},
#  'dt': 1601387276,
#  'id': 3653967,
#  'main': {'feels_like': 74.37,
#           'grnd_level': 1013,
#           'humidity': 83,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 74.43,
#           'temp_max': 74.43,
#           'temp_min': 74.43},
#  'name': 'Muisne',
#  'sys': {'country': 'EC', 'sunrise': 1601377619, 'sunset': 1601421204},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 215, 'speed': 12.71}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 21.32, 'lon': -158.01},
#  'dt': 1601387276,
#  'id': 5855051,
#  'main': {'feels_like': 76.71,
#           'humidity': 83,
#           'pressure': 1013,
#           'temp': 73.06,
#           'temp_max': 75.2,
#           'temp_min': 69.8},
#  'name': '‘Ewa Beach',
#  'sys': {'country': 'US',
#          'id': 7868,
#          'sunrise': 1601396566,
#          'sunset': 1601439678,
#          'type': 1},
#  'timezone': -36000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 39, 'speed': 4.97}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -23.85, 'lon': 151.25},
#  'dt': 1601387277,
#  'id': 2165478,
#  'main': {'feels_like': 64.58,
#           'humidity': 60,
#           'pressure': 1021,
#           'temp': 68,
#           'temp_max': 68,
#           'temp_min': 68},
#  'name': 'Gladstone',
#  'sys': {'country': 'AU',
#          'id': 9526,
#          'sunrise': 1601321842,
#          'sunset': 1601365993,
#          'type': 1},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 150, 'speed': 8.05}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -9.66, 'lon': 120.26},
#  'dt': 1601387278,
#  'id': 1622318,
#  'main': {'feels_like': 83.05,
#           'grnd_level': 1008,
#           'humidity': 77,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 79.36,
#           'temp_max': 79.36,
#           'temp_min': 79.36},
#  'name': 'Waingapu',
#  'sys': {'country': 'ID', 'sunrise': 1601329450, 'sunset': 1601373256},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 141, 'speed': 8.39}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -31.43, 'lon': 152.92},
#  'dt': 1601387279,
#  'id': 2152659,
#  'main': {'feels_like': 47.73,
#           'humidity': 81,
#           'pressure': 1024,
#           'temp': 51.37,
#           'temp_max': 52,
#           'temp_min': 50},
#  'name': 'Port Macquarie',
#  'sys': {'country': 'AU',
#          'id': 9610,
#          'sunrise': 1601321327,
#          'sunset': 1601365706,
#          'type': 1},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 350, 'speed': 4.7}}
# {'base': 'stations',
#  'clouds': {'all': 87},
#  'cod': 200,
#  'coord': {'lat': 5.26, 'lon': -0.76},
#  'dt': 1601387279,
#  'id': 2297810,
#  'main': {'feels_like': 80.8,
#           'grnd_level': 1008,
#           'humidity': 77,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 79.52,
#           'temp_max': 79.52,
#           'temp_min': 79.52},
#  'name': 'Mumford',
#  'sys': {'country': 'GH', 'sunrise': 1601358648, 'sunset': 1601402134},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 208, 'speed': 12.82}}
# {'base': 'stations',
#  'clouds': {'all': 93},
#  'cod': 200,
#  'coord': {'lat': 31.34, 'lon': 69.45},
#  'dt': 1601387280,
#  'id': 1162105,
#  'main': {'feels_like': 73.31,
#           'grnd_level': 860,
#           'humidity': 16,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 80.55,
#           'temp_max': 80.55,
#           'temp_min': 80.55},
#  'name': 'Zhob',
#  'sys': {'country': 'PK', 'sunrise': 1601342078, 'sunset': 1601385011},
#  'timezone': 18000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 260, 'speed': 6.04}}
# {'base': 'stations',
#  'clouds': {'all': 95},
#  'cod': 200,
#  'coord': {'lat': -14.97, 'lon': 22.68},
#  'dt': 1601387280,
#  'id': 915471,
#  'main': {'feels_like': 90.99,
#           'grnd_level': 897,
#           'humidity': 16,
#           'pressure': 1003,
#           'sea_level': 1003,
#           'temp': 96.17,
#           'temp_max': 96.17,
#           'temp_min': 96.17},
#  'name': 'Kalabo',
#  'sys': {'country': 'ZM', 'sunrise': 1601352796, 'sunset': 1601396738},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 73, 'speed': 6.22}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 17.33, 'lon': 42.67},
#  'dt': 1601387281,
#  'id': 105298,
#  'main': {'feels_like': 104.94,
#           'humidity': 67,
#           'pressure': 1005,
#           'temp': 95,
#           'temp_max': 95,
#           'temp_min': 95},
#  'name': 'Jizan',
#  'sys': {'country': 'SA',
#          'id': 7407,
#          'sunrise': 1601348352,
#          'sunset': 1601391589,
#          'type': 1},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 290, 'speed': 9.17}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 53.6, 'lon': 91.39},
#  'dt': 1601387281,
#  'id': 1510377,
#  'main': {'feels_like': 39.56,
#           'humidity': 65,
#           'pressure': 1021,
#           'temp': 46.4,
#           'temp_max': 46.4,
#           'temp_min': 46.4},
#  'name': 'Belyy Yar',
#  'sys': {'country': 'RU',
#          'id': 8942,
#          'sunrise': 1601337155,
#          'sunset': 1601379406,
#          'type': 1},
#  'timezone': 25200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 330, 'speed': 6.71}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 59.38, 'lon': 143.3},
#  'dt': 1601387282,
#  'id': 2122605,
#  'main': {'feels_like': 38.44,
#           'grnd_level': 1006,
#           'humidity': 79,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 45,
#           'temp_max': 45,
#           'temp_min': 45},
#  'name': 'Okhotsk',
#  'sys': {'country': 'RU', 'sunrise': 1601324820, 'sunset': 1601366830},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 222, 'speed': 7.31}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 54.05, 'lon': -128.65},
#  'dt': 1601387283,
#  'id': 5993072,
#  'main': {'feels_like': 47.44,
#           'humidity': 100,
#           'pressure': 1024,
#           'temp': 50,
#           'temp_max': 50,
#           'temp_min': 50},
#  'name': 'Kitimat',
#  'sys': {'country': 'CA',
#          'id': 984,
#          'sunrise': 1601390040,
#          'sunset': 1601432114,
#          'type': 1},
#  'timezone': -25200,
#  'visibility': 4828,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'},
#              {'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'},
#              {'description': 'fog', 'icon': '50n', 'id': 741, 'main': 'Fog'}],
#  'wind': {'deg': 20, 'speed': 4.7}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -27.8, 'lon': -64.26},
#  'dt': 1601387283,
#  'id': 3835869,
#  'main': {'feels_like': 65.97,
#           'grnd_level': 984,
#           'humidity': 27,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 78.64,
#           'temp_max': 78.64,
#           'temp_min': 78.64},
#  'name': 'Santiago del Estero',
#  'sys': {'country': 'AR', 'sunrise': 1601373465, 'sunset': 1601417789},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 16, 'speed': 19.22}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -28.65, 'lon': 153.62},
#  'dt': 1601387284,
#  'id': 2172880,
#  'main': {'feels_like': 50.74,
#           'humidity': 93,
#           'pressure': 1024,
#           'temp': 51.93,
#           'temp_max': 54,
#           'temp_min': 50},
#  'name': 'Byron Bay',
#  'sys': {'country': 'AU',
#          'id': 9496,
#          'sunrise': 1601321204,
#          'sunset': 1601365494,
#          'type': 1},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 110, 'speed': 2.24}}
# {'base': 'stations',
#  'clouds': {'all': 93},
#  'cod': 200,
#  'coord': {'lat': 6.8, 'lon': -1.08},
#  'dt': 1601387284,
#  'id': 2305537,
#  'main': {'feels_like': 89.1,
#           'grnd_level': 965,
#           'humidity': 74,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 81.9,
#           'temp_max': 81.9,
#           'temp_min': 81.9},
#  'name': 'Agogo',
#  'rain': {'1h': 0.76},
#  'sys': {'country': 'GH', 'sunrise': 1601358741, 'sunset': 1601402195},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 195, 'speed': 3.36}}
# {'base': 'stations',
#  'clouds': {'all': 29},
#  'cod': 200,
#  'coord': {'lat': 10.67, 'lon': -63.26},
#  'dt': 1601387285,
#  'id': 3646382,
#  'main': {'feels_like': 90,
#           'grnd_level': 1013,
#           'humidity': 72,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 84.33,
#           'temp_max': 84.33,
#           'temp_min': 84.33},
#  'name': 'Carupano',
#  'rain': {'1h': 0.18},
#  'sys': {'country': 'VE', 'sunrise': 1601373705, 'sunset': 1601417070},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 117, 'speed': 7.58}}
# {'base': 'stations',
#  'clouds': {'all': 31},
#  'cod': 200,
#  'coord': {'lat': 63.9, 'lon': 122.76},
#  'dt': 1601387285,
#  'id': 2021017,
#  'main': {'feels_like': 22.98,
#           'grnd_level': 996,
#           'humidity': 91,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 32.09,
#           'temp_max': 32.09,
#           'temp_min': 32.09},
#  'name': 'Kysyl-Syr',
#  'sys': {'country': 'RU', 'sunrise': 1601329903, 'sunset': 1601371603},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 256, 'speed': 9.26}}
# {'base': 'stations',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': -7.61, 'lon': -72.9},
#  'dt': 1601387285,
#  'id': 3663516,
#  'main': {'feels_like': 82.09,
#           'grnd_level': 993,
#           'humidity': 90,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 75.56,
#           'temp_max': 75.56,
#           'temp_min': 75.56},
#  'name': 'Mâncio Lima',
#  'sys': {'country': 'BR', 'sunrise': 1601375814, 'sunset': 1601419587},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 136, 'speed': 4.18}}

# %%
print(cities_weather['name'])
# Out:
# Mâncio Lima

# %%
# set up lists to hold reponse info
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
count = 0

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

for name in cities:
    
    try:
        cloudiness.append(cities_weather['list'][0]['clouds']['all'])
        date.append(cities_weather['list'][0]['dt'])
        humidity.append(cities_weather['list'][0]['main']['humidity'])
        lat.append(weather_json['city']['coord']['lat'])
        lng.append(weather_json['city']['coord']['lon'])
        max_temp.append(cities_weather['list'][0]['main']['temp_max'])
        wind_speed.append(cities_weather['list'][0]['wind']['speed'])
        count = count + 1
        print(f"Number of records {count} | {city}")  
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        pass
        
len(cities)
# Out:
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# 628

# %%
weather_data = pd.DataFrame(cities)
weather_data.head()
# Out:
#                0
# 0      dharchula
# 1     champerico
# 2       katsuura
# 3      yuancheng
# 4  leningradskiy

# %%
### Convert Raw Data to DataFrame
#Export the city data into a .csv.
#Display the DataFrame

weather_dict = {"City": cities,"Latitude": lat, "Longitude":lng,
                "Max Temp":max_temp,"Humidity":humidity,"Cloudiness":cloudiness,
                "Wind Speed":wind_speed,"Country":country, "Date":date}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-19b12718c260> in <module>
#       6                 "Max Temp":max_temp,"Humidity":humidity,"Cloudiness":cloudiness,
#       7                 "Wind Speed":wind_speed,"Country":country, "Date":date}
# ----> 8 weather_data = pd.DataFrame(weather_dict)
#       9 weather_data.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      62     # figure out the index, if necessary
#      63     if index is None:
# ---> 64         index = extract_index(arrays)
#      65     else:
#      66         index = ensure_index(index)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     363             lengths = list(set(raw_lengths))
#     364             if len(lengths) > 1:
# --> 365                 raise ValueError("arrays must all be same length")
#     366
#     367             if have_dicts:
#
# ValueError: arrays must all be same length

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
