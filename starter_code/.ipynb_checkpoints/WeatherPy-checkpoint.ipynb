# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import json

# %% [markdown]
# ## Generate Cities List

# %%
file = "../output_data/final_temp_pd.csv"
cities_df = pd.read_csv(file)
cities_df.head()
# Out:
#         City Country    Lat     Lng
# 0  ostrovnoy      RU  68.06   39.47
# 1  mahebourg      MU -20.41   57.70
# 2    qaanaaq      GL  77.47  -69.23
# 3     zhuhai      CN  22.27  113.58
# 4  cape town      ZA -33.92   18.42

# %%
len(cities_df)
# Out:
# 516

# %%
cities_df.dtypes
# Out:
# City        object
# Country     object
# Lat        float64
# Lng        float64
# dtype: object

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# create the lists in the DataFrame
cities_df['City_Name'] = ""
cities_df['Humidity'] = ""
cities_df['Max_Temp'] = ""
cities_df['Wind_Speed'] = ""
cities_df['Cloudiness'] = ""
cities_df['Date'] = ""

cities_df.head()
# Out:
#         City Country    Lat     Lng City_Name Humidity Max_Temp Wind_Speed  \
# 0  ostrovnoy      RU  68.06   39.47
# 1  mahebourg      MU -20.41   57.70
# 2    qaanaaq      GL  77.47  -69.23
# 3     zhuhai      CN  22.27  113.58
# 4  cape town      ZA -33.92   18.42
#
#   Cloudiness Date
# 0
# 1
# 2
# 3
# 4

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
weather_api_key = 'c69238b9553f803c3dbc5f5427b2aa7a'

for index, row in cities_df.iterrows():
    Lat = str(row['Lat'])
    
    Lng = str(row['Lng'])
    
    city = row['City']
    
        
    query_url = url + "lat=" + Lat +"&lon=" + Lng + '&units=Imperial' + '&appid=' + weather_api_key  
    weather_response = requests.get(query_url)
    weather_response = weather_response.json()
    
    #pprint(weather_response)
    
    try:
        cities_df.loc[index, 'City_Name'] = weather_response['base'][0]['name']
        cities_df.loc[index, 'Humidity'] = weather_response['base'][0]['main']['humidity']
        cities_df.loc[index, 'Max_Temp'] = weather_response['base'][0]['main']['temp_max']
        cities_df.loc[index, 'Wind_Speed'] = weather_response['base'][0]['wind']['speed']
        cities_df.loc[index, 'Cloudiness'] = weather_response['base'][0]['clouds']['all']
        cities_df.loc[index, 'Date'] = weather_response['base'][0]['dt']
        count = 0 + 1
        print('The reocrd count is' + count + "City" + city)
        
    except (KeyError, IndexError):
        print('Record not found')
        pass
        
len(cities_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-5dc8d4b86c16> in <module>
#      17
#      18     try:
# ---> 19         cities_df.loc[index, 'City_Name'] = weather_response['base'][0]['name']
#      20         cities_df.loc[index, 'Humidity'] = weather_response['base'][0]['main']['humidity']
#      21         cities_df.loc[index, 'Max_Temp'] = weather_response['base'][0]['main']['temp_max']
#
# TypeError: string indices must be integers

# %%
file2="../output_data/cities2.csv"

# %%
weather_data = pd.read_csv(file2)
weather_data_df = pd.DataFrame(weather_data)
weather_data_df.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  ostrovnoy           2      RU  1558378754        72  68.05   39.51
# 1  mahebourg          75      MU  1558378503        74 -20.41   57.70
# 2    qaanaaq          25      GL  1558378755        73  77.48  -69.36
# 3     zhuhai           0      CN  1558378755        39  40.71  112.04
# 4  cape town          20      ZA  1558378755        76 -33.93   18.42
#
#    Max_Temp  Wind_Speed
# 0     37.50        7.16
# 1     78.80       11.41
# 2     22.20        2.37
# 3     44.60        4.47
# 4     55.99        8.05

# %%
### Convert Raw Data to DataFrame
#Export the city data into a .csv.
#Display the DataFrame

weather_data = pd.DataFrame(weather_data_df)
weather_data.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  ostrovnoy           2      RU  1558378754        72  68.05   39.51
# 1  mahebourg          75      MU  1558378503        74 -20.41   57.70
# 2    qaanaaq          25      GL  1558378755        73  77.48  -69.36
# 3     zhuhai           0      CN  1558378755        39  40.71  112.04
# 4  cape town          20      ZA  1558378755        76 -33.93   18.42
#
#    Max_Temp  Wind_Speed
# 0     37.50        7.16
# 1     78.80       11.41
# 2     22.20        2.37
# 3     44.60        4.47
# 4     55.99        8.05

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_data
# Out:
#                   City  Cloudiness Country        Date  Humidity    Lat  \
# 0            ostrovnoy           2      RU  1558378754        72  68.05
# 1            mahebourg          75      MU  1558378503        74 -20.41
# 2              qaanaaq          25      GL  1558378755        73  77.48
# 3               zhuhai           0      CN  1558378755        39  40.71
# 4            cape town          20      ZA  1558378755        76 -33.93
# 5               atuona          78      PF  1558378755        76  -9.80
# 6             flinders           0      AU  1558378755        62 -34.58
# 7                opuwo           0     NaN  1558378523        23 -18.06
# 8                tiksi          95      RU  1558378756        88  71.64
# 9    pushkinskiye gory           6      RU  1558378756        70  57.02
# 10              aykhal          90      RU  1558378756        48  65.95
# 11              castro           0      CL  1558378756        70 -42.48
# 12              avarua         100      CK  1558378756        94 -21.21
# 13           saskylakh           0      RU  1558378757        91  71.97
# 14        constitucion           5      MX  1558378757         4  23.99
# 15              albany          40      US  1558378727        45  42.65
# 16            vilyuysk          16      RU  1558378757        59  63.75
# 17             ushuaia          75      AR  1558378606        75 -54.81
# 18     bambous virieux          75      MU  1558378758        74 -20.34
# 19             kodinsk          14      RU  1558378758        81  58.60
# 20              teknaf           1      BD  1558378758        85  20.86
# 21           busselton          84      AU  1558378758        63 -33.64
# 22               ambon          11      FR  1558378758        93  47.55
# 23            maragogi          97      BR  1558378610        69  -9.01
# 24              fallon          90      US  1558378758        53  46.84
# 25             kantang          20      TH  1558378759        94   7.42
# 26         colonelganj           0      IN  1558378759        14  27.13
# 27        punta arenas          40      CL  1558378759        61 -53.16
# 28             rikitea          95      PF  1558378669        76 -23.12
# 29         new norfolk          40      AU  1558378759        66 -42.78
# ..                 ...         ...     ...         ...       ...    ...
# 518             bonito           0      BR  1558378893        49 -21.13
# 519      saint anthony          90      US  1558378893        81  43.97
# 520       high prairie           0      CA  1558378893        34  55.43
# 521          high rock          75      BS  1558378893        83  26.63
# 522          raudeberg          20      NO  1558378894        76  61.99
# 523          kununurra          75      AU  1558378894        58 -15.77
# 524          mogadishu          79      SO  1558378801        79   2.04
# 525              mecca           1      SA  1558378872        48  21.43
# 526             viedma          14      AR  1558378894        41 -40.81
# 527           tomatlan           0      MX  1558378894        59  19.93
# 528             lyuban          39      BY  1558378625        68  52.80
# 529          bonavista          59      CA  1558378895        74  48.65
# 530             hirara          37      JP  1558378895        67  24.80
# 531            russell          75      AR  1558378895        71 -33.01
# 532         burns lake          66      CA  1558378895        62  54.23
# 533            hakkari           0      FI  1558378896        46  61.34
# 534             marzuq          84      YE  1558378896        36  14.40
# 535       villaviciosa          20      ES  1558378896        71  43.48
# 536             padang         100      ID  1558378896        82  -0.92
# 537              matam           1      SN  1558378897        14  15.66
# 538   la seyne-sur-mer           0      FR  1558378897        72  43.10
# 539               palu          72      ID  1558378897        80  -0.90
# 540           talmenka          40      RU  1558378897        76  53.82
# 541           tamworth          64      AU  1558378897        87 -31.09
# 542              perth          20      GB  1558378872        82  56.40
# 543             yabrud           0      SY  1558378840        32  33.97
# 544            paraiso           5      MX  1558378898         4  24.01
# 545            veraval           0      FR  1558378898        62  49.65
# 546        novyy urgal         100      RU  1558378899        93  51.07
# 547            tongren           4      CN  1558378899        64  27.72
#
#         Lng  Max_Temp  Wind_Speed
# 0     39.51     37.50        7.16
# 1     57.70     78.80       11.41
# 2    -69.36     22.20        2.37
# 3    112.04     44.60        4.47
# 4     18.42     55.99        8.05
# 5   -139.03     81.96       16.49
# 6    150.85     60.01       11.41
# 7     13.84     72.06        5.44
# 8    128.87     14.10       15.70
# 9     28.91     65.04        6.93
# 10   111.51     39.20       11.18
# 11   -73.76     48.20        9.17
# 12  -159.78     71.60        2.24
# 13   114.09      4.92        2.26
# 14  -104.67     84.20       16.11
# 15   -73.75     82.40       12.75
# 16   121.63     34.62        5.84
# 17   -68.31     44.60       36.91
# 18    57.76     78.80       11.41
# 19    99.18     48.84        4.97
# 20    92.31     84.66        8.23
# 21   115.35     55.00       12.86
# 22    -2.56     64.99        5.82
# 23   -35.22     83.94        9.42
# 24  -105.12     51.80       18.34
# 25    99.52     78.80        6.93
# 26    81.70     94.20        5.08
# 27   -70.91     50.00       46.08
# 28  -134.97     74.58       12.82
# 29   147.06     57.99        5.82
# ..      ...       ...         ...
# 518  -56.49     84.30        7.72
# 519 -111.68     45.00        3.36
# 520 -116.48     61.80       16.46
# 521  -78.28     75.20       12.75
# 522    5.14     69.80        4.70
# 523  128.74     82.40        6.93
# 524   45.34     80.88        9.78
# 525   39.83     88.62        1.74
# 526  -62.99     58.56       10.98
# 527 -105.25     84.66        7.90
# 528   28.00     67.92       12.15
# 529  -53.11     44.01       15.99
# 530  125.28     75.48       26.15
# 531  -68.80     50.00       12.75
# 532 -125.76     56.40        5.21
# 533   23.75     69.80        5.82
# 534   46.47     79.44        6.02
# 535   -5.43     59.00        6.93
# 536  100.36     81.24        7.65
# 537  -13.26    102.12       11.61
# 538    5.88     69.01        2.24
# 539  119.87     78.72        3.83
# 540   83.56     51.80       11.18
# 541  150.93     44.60        5.82
# 542   -3.43     59.00        3.36
# 543   36.66     80.60        8.05
# 544 -104.61     84.20       16.11
# 545    0.71     61.00        8.05
# 546  132.56     49.74        2.68
# 547  109.18     55.86        2.84
#
# [548 rows x 9 columns]

# %%
#  Get the indices of cities that have humidity over 100%.
# does not apply

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
#does not apply

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
scatlat = weather_data["Lat"]
scattemp = weather_data["Max_Temp"]

plt.scatter(scatlat,scattemp)
plt.title('Latitude vs. Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('../output_data/scatplotlatitudemaxtemp.jpg')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
scatlat = weather_data["Lat"]
scathum = weather_data["Humidity"]

plt.scatter(scatlat,scathum)
plt.title('Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Percent Humidity %')
plt.savefig('../output_data/scatplotlatitudemaxhumidity.jpg')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
scatlat = weather_data["Lat"]
scatcloud = weather_data["Cloudiness"]

plt.scatter(scatlat,scatcloud)
plt.title('Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.savefig('../output_data/latcloud.jpg')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
catlat = weather_data["Lat"]
scatwind = weather_data["Wind_Speed"]

plt.scatter(scatlat,scatwind)
plt.title('Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed in MPH')
plt.savefig('../output_data/scatplotwindspeed.jpg')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=14,color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
northlat_df = weather_data.loc[weather_data["Lat"] >= 0,:]
southlat_df = weather_data.loc[weather_data["Lat"] < 0,:]

northlat_df.head()
# Out:
#                 City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0          ostrovnoy           2      RU  1558378754        72  68.05   39.51
# 2            qaanaaq          25      GL  1558378755        73  77.48  -69.36
# 3             zhuhai           0      CN  1558378755        39  40.71  112.04
# 8              tiksi          95      RU  1558378756        88  71.64  128.87
# 9  pushkinskiye gory           6      RU  1558378756        70  57.02   28.91
#
#    Max_Temp  Wind_Speed
# 0     37.50        7.16
# 2     22.20        2.37
# 3     44.60        4.47
# 8     14.10       15.70
# 9     65.04        6.93

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northlat_df["Lat"]
y_values = northlat_df["Max_Temp"]
plot_linear_regression(x_values,y_values,'Max_Temp',(6,30))

plt.savefig('../output_data/northernregresstemp.jpg')
plt.show()
# Out:
# The r-squared is: -0.8151657406810829

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southlat_df["Lat"]
y_values = southlat_df["Max_Temp"]
plot_linear_regression(x_values,y_values,'Max_Temp',(6,30))

plt.savefig('../output_data/southernregresstem.jpg')
plt.show()
# Out:
# The r-squared is: 0.7602633550516462

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
