# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from pprint import pprint

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
base_url = 'https://maps.googleapis.com/maps/api/geocode/json'

file = "../output_data/cities.csv"

temp_pd = pd.read_csv(file)

temp_pd["Lat"] = ""
temp_pd["Lng"] = ""

temp_pd.head()
# Out:
#         City Country Lat Lng
# 0  ostrovnoy      RU
# 1  mahebourg      MU
# 2    qaanaaq      GL
# 3     zhuhai      CN
# 4  cape town      ZA

# %%
params = {"key": g_key}
count = 0

# %%
for index, row in temp_pd.iterrows():
    city = row['City']
    country = row['Country']
   
    params['address'] = f"{city},{country}"
    
    cities_lat_lng = requests.get(base_url, params=params)
    cities_lat_lng = cities_lat_lng.json()
    #pprint(cities_lat_lng)
    
    try:
        temp_pd.loc[index, "Lat"] = cities_lat_lng["results"][0]['geometry']['location']['lat']
        temp_pd.loc[index, "Lng"] = cities_lat_lng['results'][0]['geometry']['location']['lng']
        count += 1
        print(f'The record count is {count} City: {city}')
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
    
temp_pd.head()
# Out:
# The record count is 2 City: ostrovnoy
# The record count is 3 City: mahebourg
# The record count is 4 City: qaanaaq
# The record count is 5 City: zhuhai
# The record count is 6 City: cape town
# The record count is 7 City: atuona
# The record count is 8 City: flinders
# The record count is 9 City: opuwo
# The record count is 10 City: tiksi
# The record count is 11 City: pushkinskiye gory
# The record count is 12 City: aykhal
# The record count is 13 City: castro
# The record count is 14 City: avarua
# The record count is 15 City: saskylakh
# Missing field/result... skipping.
# The record count is 16 City: albany
# The record count is 17 City: vilyuysk
# The record count is 18 City: ushuaia
# The record count is 19 City: bambous virieux
# The record count is 20 City: kodinsk
# The record count is 21 City: teknaf
# The record count is 22 City: busselton
# The record count is 23 City: ambon
# The record count is 24 City: maragogi
# The record count is 25 City: fallon
# ...

# %%
final_temp_pd = pd.DataFrame(temp_pd)
final_temp_pd.to_csv("../output_data/final_temp_pd.csv", index=False, header=True)

# %%
Humidity = cleaned_weather_data['Humidity']
temp_pd.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-26a15bd9260e> in <module>
# ----> 1 Humidity = cleaned_weather_data['Humidity']
#       2 temp_pd.dtypes
#
# NameError: name 'cleaned_weather_data' is not defined

# %%
file1 = "../output_data/cleaned_weather_data.csv"
humidity_heatmap = pd.read_csv(file1)
humidity_heatmap.head()
# Out:
#    Unnamed: 0       City Country    Lat     Lng     City_Name  Humidity  \
# 0           0  ostrovnoy      RU  68.06   39.47     Ostrovnoy        81
# 1           1  mahebourg      MU -20.41   57.70     Mahébourg        83
# 2           2    qaanaaq      GL  77.47  -69.23       Qaanaaq        80
# 3           3     zhuhai      CN  22.27  113.58        Zhuhai        79
# 4           4  cape town      ZA -33.92   18.42  De Waterkant        76
#
#    Max_Temp  Wind_Speed  Cloudiness        Date
# 0     45.41       16.33           0  1601435961
# 1     71.60       11.41          75  1601435962
# 2     12.33        6.96           2  1601435962
# 3     91.99        5.82          20  1601435962
# 4     53.60       10.29          17  1601435963

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
Humidity = humidity_heatmap['Humidity']
gmaps.configure(api_key=g_key)

fig = gmaps.figure()

locations = humidity_heatmap[['Lat','Lng']]
heat_layer = gmaps.heatmap_layer(locations, weights=Humidity,
                                dissipating=False, max_intensity=100,
                                point_radius = 1)
fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
humidity_heatmap['Hotel Name']= ""
hotel_df = pd.DataFrame(humidity_heatmap)
 
hotel_df
# Out:
#      Unnamed: 0               City Country    Lat     Lng  \
# 0             0          ostrovnoy      RU  68.06   39.47
# 1             1          mahebourg      MU -20.41   57.70
# 2             2            qaanaaq      GL  77.47  -69.23
# 3             3             zhuhai      CN  22.27  113.58
# 4             4          cape town      ZA -33.92   18.42
# 5             5             atuona      PF  -9.80 -139.04
# 6             6           flinders      AU -35.02  138.57
# 7             7              tiksi      RU  71.64  128.86
# 8             8  pushkinskiye gory      RU  57.02   28.91
# 9             9             aykhal      RU  65.94  111.49
# 10           10             castro      CL -42.48  -73.76
# 11           11             avarua      CK -21.21 -159.78
# 12           12          saskylakh      RU  71.95  114.12
# 13           13             albany      US  42.65  -73.76
# 14           14           vilyuysk      RU  63.75  121.63
# ...

# %%
base_url1 = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
count = 0
g_key = "AIzaSyCKTNg9F8RvUYuTMfntKABfeR-MHKtLGbM"

for index, row in hotel_df.iterrows(): 
    latitude = str(row['Lat'])
    longitude = str(row['Lng'])
    city = row['City']
    country = row['Country']
    
    #print(f"Results for Index {index}: {city}.")
    response = requests.get(f"{base_url1}?location={latitude},{longitude}&radius=5000&type=hotel&keyword={city}&key={g_key}") 
    #print(response)
    
    results = response.json()                     
     
   
    try:
        hotel_df.loc[index, 'Hotel Name'] = results['results'][0]['name']
        count += 1
        print(f'The record count is {count} City: {city}')
    except:
        print("skipping no record found results")
len(hotel_df)
# Out:
# The record count is 1 City: ostrovnoy
# The record count is 2 City: mahebourg
# The record count is 3 City: qaanaaq
# The record count is 4 City: zhuhai
# The record count is 5 City: cape town
# The record count is 6 City: atuona
# The record count is 7 City: flinders
# The record count is 8 City: tiksi
# The record count is 9 City: pushkinskiye gory
# The record count is 10 City: aykhal
# The record count is 11 City: castro
# The record count is 12 City: avarua
# The record count is 13 City: saskylakh
# The record count is 14 City: albany
# The record count is 15 City: vilyuysk
# The record count is 16 City: ushuaia
# The record count is 17 City: bambous virieux
# The record count is 18 City: kodinsk
# The record count is 19 City: teknaf
# The record count is 20 City: busselton
# The record count is 21 City: ambon
# The record count is 22 City: maragogi
# The record count is 23 City: fallon
# The record count is 24 City: kantang
# The record count is 25 City: colonelganj
# ...

# %%
hotel_df
# Out:
#      Unnamed: 0               City Country    Lat     Lng  \
# 0             0          ostrovnoy      RU  68.06   39.47
# 1             1          mahebourg      MU -20.41   57.70
# 2             2            qaanaaq      GL  77.47  -69.23
# 3             3             zhuhai      CN  22.27  113.58
# 4             4          cape town      ZA -33.92   18.42
# 5             5             atuona      PF  -9.80 -139.04
# 6             6           flinders      AU -35.02  138.57
# 7             7              tiksi      RU  71.64  128.86
# 8             8  pushkinskiye gory      RU  57.02   28.91
# 9             9             aykhal      RU  65.94  111.49
# 10           10             castro      CL -42.48  -73.76
# 11           11             avarua      CK -21.21 -159.78
# 12           12          saskylakh      RU  71.95  114.12
# 13           13             albany      US  42.65  -73.76
# 14           14           vilyuysk      RU  63.75  121.63
# ...

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
marker_layer = gmaps.symbol_layer(
    locations, fill_color='rgba(0, 150, 0, 0.4)',
    stroke_color='rgba(0, 0, 150, 0.4)', scale=2
)


fig = gmaps.figure()
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

fig

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
